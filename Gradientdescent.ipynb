# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedantjha-13/25_VEDANTJHA_D2/blob/main/Gradientdescent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %%
X,y = make_regression(n_samples=300, n_features=1, n_informative=1, n_targets=1,noise=40,random_state=13)

# %%
plt.scatter(X,y)

# %%
m_arr = np.linspace(-150, 150, 10)
b_arr = np.linspace(-150, 150, 10)
mGrid, bGrid = np.meshgrid(m_arr,b_arr)

final = np.column_stack((mGrid.ravel(), bGrid.ravel()))

z_arr = []

for i in range(final.shape[0]):
    z_arr.append(np.sum((y - final[i,0]*X.reshape(300) - final[i,1])**2))

z_arr = np.array(z_arr).reshape(10,10)

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Surface(x = m_arr, y = b_arr, z =z_arr)])

fig.update_layout(title='Cost Function', autosize=False,
                  width=500, height=500,
                  margin=dict(l=65, r=50, b=65, t=90))



fig.show()

fig.write_html("cost_function.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e81a3460-660f-4bd6-bec8-d6b65c9f41d2" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e81a3460-660f-4bd6-bec8-d6b65c9f41d2")) {                    Plotly.newPlot(                        "e81a3460-660f-4bd6-bec8-d6b65c9f41d2",                        [{"x":[-150.0,-116.66666666666666,-83.33333333333333,-50.0,-16.666666666666657,16.666666666666686,50.0,83.33333333333334,116.66666666666669,150.0],"y":[-150.0,-116.66666666666666,-83.33333333333333,-50.0,-16.666666666666657,16.666666666666686,50.0,83.33333333333334,116.66666666666669,150.0],"z":[[20418900.50169692,16743844.457132623,13662059.255954614,11173544.898162887,9278301.383757439,7976328.712738277,7267626.8851053985,7152195.900858802,7630035.759998488,8701146.462524455],[17987620.676946655,14281514.587551463,11168679.341542557,8649114.938919934,6722821.379683591,5389798.6638335325,4650046.791369757,4503565.762292262,4950355.576601053,5990416.2342961235],[16223007.51886306,12485851.384636972,9341966.09379717,6791351.6463436475,4834008.042276409,3469935.2815954536,2699133.364300781,2521602.2903923914,2937342.059870284,3946352.6727344585],[15125061.027446132,11356854.848389149,8181919.512718447,5600255.020434029,3611861.3715358945,2216738.5660240417,1414886.6038984726,1206305.485159186,1590995.209806182,2568955.77783946],[14693781.202695869,10894524.97880799,7688539.598306391,5075825.061191078,3056381.3674620455,1630208.5171192961,797306.5101628306,557675.3465926469,911315.0264087463,1858225.5496111275],[14929168.044612274,11098861.775893496,7861826.350561003,5218061.768614792,3167568.030054864,1710345.134881218,846393.0830938555,575711.8746927751,898301.5096779779,1814161.9880494627],[15831221.553195346,11969865.239645671,8701779.769482281,6026965.142705174,3945421.3593143476,2457148.4193098056,1562146.3226915468,1260415.0694595696,1551954.6596138757,2436765.093154464],[17399941.728445083,13507535.370064514,10208399.855070226,7502535.183462222,5389941.3552405,3870618.370405061,2944566.228955905,2611784.9308930314,2872274.47621644,3726034.8649261314],[19635328.57036149,15711872.167150022,12381686.607324839,9644771.890885938,7501128.017833319,5950754.988166983,4993652.801886931,4629821.458993159,4859260.959485672,5681971.303364467],[22537382.07894456,18582875.630902197,15221640.026246116,12453675.264976319,10278981.347092802,8697558.27259557,7709406.04148462,7314524.653759954,7512914.109421569,8304574.408469467]],"type":"surface"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap ...

# %%
b = 150
m = -127.82
lr = 0.001
all_b = []
all_m = []
all_cost = []

epochs = 30

for i in range(epochs):
    slope_b = 0
    slope_m = 0
    cost = 0
    for j in range(X.shape[0]):
        slope_b = slope_b - 2*(y[j] - (m * X[j]) -  b)
        slope_m = slope_m - 2*(y[j] - (m * X[j]) -  b)*X[j]
        cost = cost + (y[j] - m * X[j] -b) ** 2

    b = b - (lr * slope_b)
    m = m - (lr * slope_m)
    all_b.append(b)
    all_m.append(m)
    all_cost.append(cost)

# %%
import plotly.express as px

fig = px.scatter_3d(x=np.array(all_m).ravel(), y=np.array(all_b).ravel(), z=np.array(all_cost).ravel()*100)

fig.add_trace(go.Surface(x = m_arr, y = b_arr, z =z_arr*100 ))

fig.show()

fig.write_html("cost_function2.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d7324932-1443-4fe4-9c84-bf4fce474773" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7324932-1443-4fe4-9c84-bf4fce474773")) {                    Plotly.newPlot(                        "d7324932-1443-4fe4-9c84-bf4fce474773",                        [{"hovertemplate":"x=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003ez=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[-12.128616483611793,39.09500527617998,61.98041238661121,72.2912284203695,76.97249206445328,79.11261357111613,80.0970420207326,80.55231690445028,80.7638597148196,80.86254974127243,80.90874971492958,80.93044051888451,80.94064933932641,80.94546403705826,80.94773865461129,80.94881479328755,80.94932452632807,80.94956620773445,80.94968088978227,80.94973534476954,80.94976121609557,80.94977351300955,80.94977936003504,80.94978214106952,80.9497834641508,80.94978409373799,80.94978439337702,80.9497845360037,80.94978460390098,80.9497846362264],"y":[53.5582157374222,18.21450241265019,5.508463259579564,1.065581223428305,-0.4234354209500082,-0.8882239772886908,-1.0143336179712605,-1.037267581500227,-1.0337184919169806,-1.0263872837126216,-1.0206969036597278,-1.0171296915106542,-1.015096656259327,-1.0139981562596443,-1.0134242093373913,-1.0131310662891948,-1.0129837363311884,-1.012910559837602,-1.0128745354435156,-1.0128569208914264,-1.0128483533237758,-1.0128442033214655,-1.0128421996827848,-1.0128412348319489,-1.0128407711754936,-1.0128405487393524,-1.0128404421710557,-1.012840391170313,-1.0128403667843067,-1.0128403551325122],"z":[1984000973.5686824,382988152.70357376,108268675.66672808,59388478.404394336,50341713.32391084,48599615.7852997,48251537.82129902,48179733.783513285,48164532.28750688,48161248.98044078,48160529.24734491,48160369.78577711,48160334.19048863,48160326.20354258,48160324.405037954,48160323.99907031,48160323.90728334,48160323.88650795,48160323.88180208,48160323.88073561,48160323.88049386,48160323.880439,48160323.88042658,48160323.88042376,48160323.88042314,48160323.88042298,48160323.88042295,48160323.88042295,48160323.88042293,48160323.88042291],"type":"scatter3d"},{"x":[-150.0,-116.66666666666666,-83.33333333333333,-50.0,-16.666666666666657,16.666666666666686,50.0,83.33333333333334,116.66666666666669,150.0],"y":[-150.0,-116.66666666666666,-83.33333333333333,-50.0,-16.666666666666657,16.666666666666686,50.0,83.33333333333334,116.66666666666669,150.0],
.762292262,4950355.576601053,5990416.2342961235],[16223007.51886306,12485851.384636972,9341966.09379717,6791351.6463436475,4834008.042276409,3469935.2815954536,2699133.364300781,2521602.2903923914,2937342.059870284,3946352.6727344585],[15125061.027446132,11356854.848389149,8181919.512718447,5600255.020434029,3611861.3715358945,2216738.5660240417,1414886.6038984726,1206305.485159186,1590995.209806182,2568955.77783946],[14693781.202695869,10894524.97880799,7688539.598306391,5075825.061191078,3056381.3674620455,1630208.5171192961,797306.5101628306,557675.3465926469,911315.0264087463,1858225.5496111275],[14929168.044612274,11098861.775893496,7861826.350561003,5218061.768614792,3167568.030054864,1710345.134881218,846393.0830938555,575711.8746927751,898301.5096779779,1814161.9880494627],[15831221.553195346,11969865.239645671,8701779.769482281,6026965.142705174,3945421.3593143476,2457148.4193098056,1562146.3226915468,1260415.0694595696,1551954.6596138757,2436765.093154464],[17399941.728445083,13507535.370064514,10208399.855070226,7502535.183462222,5389941.3552405,3870618.370405061,2944566.228955905,2611784.9308930314,2872274.47621644,3726034.8649261314],[19635328.57036149,15711872.167150022,12381686.607324839,9644771.890885938,7501128.017833319,5950754.988166983,4993652.801886931,4629821.458993159,4859260.959485672,5681971.303364467],[22537382.07894456,18582875.630902197,15221640.026246116,12453675.264976319,10278981.347092802,8697558.27259557,7709406.04148462,7314524.653759954,7512914.109421569,8304574.408469467]],"type":"contour"}],                        {"template":{"data":{"histogram2 ...

# %%
import numpy as np
import matplotlib.pyplot as plt


fig,ax=plt.subplots(1,1)
plt.figure(figsize=(18,4))
cp = ax.contourf(m_arr, b_arr, z_arr)
ax.plot(np.array(all_m).ravel(),np.array(all_b).ravel(),color='white')
fig.colorbar(cp) # Add a colorbar to a plot
ax.set_title('Filled Contours Plot')
ax.set_xlabel('m')
ax.set_ylabel('b')
plt.show()
# Out:
# <div id='0f15e5f4-a794-4288-9e31-d41e7406fd5e'></div>
# <div id='7ccb67cb-47ba-488d-a2a9-7c20bd943809'></div>

# %%
# %matplotlib notebook
from matplotlib.animation import FuncAnimation
import matplotlib.animation as animation

# intercept graph
num_epochs = list(range(0,30))
fig = plt.figure(figsize=(9,5))
axis = plt.axes(xlim =(-150, 150), ylim =(-150, 150))

axis.contourf(m_arr, b_arr, z_arr)

line, = axis.plot([], [], lw = 2,color='white')

xdata, ydata = [], []

# animation function
def animate(i):
    label = 'epoch {0}'.format(i + 1)
    xdata.append(all_m[i])
    ydata.append(all_b[i])
    line.set_data(xdata, ydata)
    axis.set_xlabel(label)

    return line,

# calling the animation function
anim = animation.FuncAnimation(fig, animate, frames = 30,repeat=False, interval = 500)

#f = r"animation8.gif"
#writergif = animation.PillowWriter(fps=2)
#anim.save(f, writer=writergif)
# Out:
# <div id='9ee21c27-6a41-4e22-9ae0-1b555e2ad873'></div>
